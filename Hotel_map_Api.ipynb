# %% [markdown]
# # Creacion Mapa

# %%
import pandas as pd

# %%
df = pd.read_csv("Data/df_hotels_22&21.csv", sep=',', encoding='latin-1')
pd.options.display.max_columns = None
df.head()
# Out:
#    Unnamed: 0                                Hotel           Location  \
# 0           0        Rosewood Castiglion del Bosco         Montalcino
# 1           1                          Grace Hotel          Santorini
# 2           2  Waldorf Astoria Maldives Ithaafushi  Ithaafushi Island
# 3           3                  Pickering House Inn          Wolfeboro
# 4           4                  One&Only Reethi Rah  North MalÃ© Atoll
#
#          Country          Region                       Company  Score  Rank  \
# 0          Italy          Europe  Massimo and Chiara Ferragamo  99.25     1
# 1         Greece          Europe    Auberge Resorts Collection  99.22     2
# 2       Maldives  Southeast Asia                        Hilton  99.11     3
# 3  United States   North America        Peter and Patty Cooke   98.95     4
# 4       Maldives  Southeast Asia         Kerzner International  98.93     5
#
#    Rooms Hotel_type        Theme  Year  Century  2021_Rank  Past_rank  \
# ...

# %%
# df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df.head(1)
# Out:
#                            Hotel    Location Country  Region  \
# 0  Rosewood Castiglion del Bosco  Montalcino   Italy  Europe
#
#                         Company  Score  Rank  Rooms Hotel_type        Theme  \
# 0  Massimo and Chiara Ferragamo  99.25     1     53      Small  Countryside
#
#    Year  Century  2021_Rank  Past_rank  Rank_Year
# 0  2000       21        0.0        0.0       2022

# %%
df_map = df[["Hotel", "Location", "Country", "Region"]]
df_map.head(1)
# Out:
#                            Hotel    Location Country  Region
# 0  Rosewood Castiglion del Bosco  Montalcino   Italy  Europe

# %%
def join_columns(row):
    return f"{row['Location']}, {row['Country']}"

df_map["Address"] = df_map.apply(join_columns, axis=1)
# Out:
# /var/folders/lp/q6v12hf56txcxrk49r3k95_c0000gn/T/ipykernel_771/2532362587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_map["Address"] = df_map.apply(join_columns, axis=1)

# %%
df_map.head(1)
# Out:
#                            Hotel    Location Country  Region  \
# 0  Rosewood Castiglion del Bosco  Montalcino   Italy  Europe
#
#              Address
# 0  Montalcino, Italy

# %% [markdown]
# Utilizar una base de datos de ciudades y coordenadas: existen diferentes bases de datos que contienen información sobre ciudades y sus coordenadas. Una opción es utilizar una base de datos como GeoNames, que ofrece una API gratuita para acceder a esta información. Para usarla, debes registrarte en la página de GeoNames y obtener una clave de API. Luego, puedes realizar peticiones a la API para obtener las coordenadas de una ciudad en particular.

# %% [markdown]
# Address Geocoding Webservice
# Find lat/lng for Address
# Returns the location lat/lng for a given address.
# Url : api.geonames.org/geoCodeAddress?
# Parameters : q (query term, url encoded)
# Optional Parameters: country (iso countrycode), postalcode
# Restriction : this webservice is only available for selected countries, see list below.
# Result : returns the nearest address for the given latitude/longitude.
# Example http://api.geonames.org/geoCodeAddress?q=Museumplein+6+amsterdam&username=demo
#
# This service is also available in JSON format :
# http://api.geonames.org/geoCodeAddressJSON?q=Museumplein+6+amsterdam&username=demo

# %% [raw]
# # para la API
# 1- tengo la contraseña de mi api guardada
# 2- añado las coordenadas a mi data set
#
# import requests
#
# # Dirección que desea geocodificar
# address = "Ciudad de México, México"
#
# # Su clave de API de Google Maps
# api_key = "YOUR_API_KEY" --> me creo el git ignore
#
# # Construye la URL de la API de geocodificación de Google Maps
# url = f"https://maps.googleapis.com/maps/api/geocode/json?address={address}&key={api_key}"
#
# # Envía una solicitud a la API y obtiene la respuesta
# response = requests.get(url)
#
# # Carga la respuesta en formato JSON
# data = response.json()
#
# # Obtiene las coordenadas de la primera ubicación en la respuesta
# location = data["results"][0]["geometry"]["location"]
#
# # Extrae la latitud y la longitud de la ubicación
# latitude = location["lat"]
# longitude = location["lng"]
#
# print(f"Latitude: {latitude}")
# print(f"Longitude: {longitude}")
